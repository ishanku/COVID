# %%
import json
import pandas as pd
import requests
from pandas.io.json import json_normalize

# %%
url="https://covid-19-statistics.p.rapidapi.com/reports";
headers = {
#'x-rapidapi-host': "covid19-monitor-pro.p.rapidapi.com",
'x-rapidapi-key': "69a2a479b7msheb974da9ba512eep14ac07jsn1360d4b1636c"
}
response = requests.request("GET", url, headers=headers)
#response = requests.get(url).json()
#covidall=json.dumps(response, indent=4, sort_keys=True)

# %%
response.json()
# Out:
# {'data': [{'date': '2020-04-26',
#    'confirmed': 5498,
#    'deaths': 174,
#    'recovered': 0,
#    'confirmed_diff': 245,
#    'deaths_diff': 8,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:52',
#    'active': 5324,
#    'active_diff': 237,
#    'fatality_rate': 0.0316,
#    'region': {'iso': 'USA',
#     'name': 'US',
#     'province': 'South Carolina',
#     'lat': '33.8569',
#     'long': '-80.9450',
#     'cities': [{'name': 'Abbeville',
#       'date': '2020-04-26',
#       'fips': 45001,
#       'lat': '34.22333378',
#       'long': '-82.46170658',
#       'confirmed': 27,
#       'deaths': 0,
#       'confirmed_diff': 3,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Aiken',
#       'date': '2020-04-26',
#       'fips': 45003,
#       'lat': '33.54338026',
#       'long': '-81.63645384',
#       'confirmed': 89,
#       'deaths': 6,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Allendale',
#       'date': '2020-04-26',
#       'fips': 45005,
#       'lat': '32.98837386',
#       'long': '-81.35321066',
#       'confirmed': 8,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Anderson',
#       'date': '2020-04-26',
#       'fips': 45007,
#       'lat': '34.51828081',
#       'long': '-82.63959517',
#       'confirmed': 145,
#       'deaths': 6,
#       'confirmed_diff': 7,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Bamberg',
#       'date': '2020-04-26',
#       'fips': 45009,
#       'lat': '33.21927586',
#       'long': '-81.05659969',
#       'confirmed': 8,
#       'deaths': 0,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Barnwell',
#       'date': '2020-04-26',
#       'fips': 45011,
#       'lat': '33.26679302',
#       'long': '-81.43584352',
#       'confirmed': 15,
#       'deaths': 0,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Beaufort',
#       'date': '2020-04-26',
#       'fips': 45013,
#       'lat': '32.39226291',
#       'long': '-80.72619758',
#       'confirmed': 255,
#       'deaths': 10,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Berkeley',
#       'date': '2020-04-26',
#       'fips': 45015,
#       'lat': '33.20222596',
#       'long': '-79.94654523',
#       'confirmed': 181,
#       'deaths': 8,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Calhoun',
#       'date': '2020-04-26',
#       'fips': 45017,
#       'lat': '33.66926881',
#       'long': '-80.77722168',
#       'confirmed': 6,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Charleston',
#       'date': '2020-04-26',
#       'fips': 45019,
#       'lat': '32.82487866',
#       'long': '-79.96512315',
#       'confirmed': 436,
#       'deaths': 6,
#       'confirmed_diff': 12,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Cherokee',
#       'date': '2020-04-26',
#       'fips': 45021,
#       'lat': '35.05122251',
#       'long': '-81.61828622',
#       'confirmed': 14,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Chester',
#       'date': '2020-04-26',
#       'fips': 45023,
#       'lat': '34.69249168',
#       'long': '-81.1583216',
#       'confirmed': 27,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Chesterfield',
#       'date': '2020-04-26',
#       'fips': 45025,
#       'lat': '34.64137396',
#       'long': '-80.15640140000002',
#       'confirmed': 44,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Clarendon',
#       'date': '2020-04-26',
#       'fips': 45027,
#       'lat': '33.66610974',
#       'long': '-80.21647898',
#       'confirmed': 181,
#       'deaths': 11,
#       'confirmed_diff': 9,
#       'deaths_diff': 2,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Colleton',
#       'date': '2020-04-26',
#       'fips': 45029,
#       'lat': '32.87582989',
#       'long': '-80.67641292',
#       'confirmed': 26,
#       'deaths': 4,
#       'confirmed_diff': 0,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Darlington',
#       'date': '2020-04-26',
#       'fips': 45031,
#       'lat': '34.33358335',
#       'long': '-79.96027485',
#       'confirmed': 104,
#       'deaths': 1,
#       'confirmed_diff': 1,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Dillon',
#       'date': '2020-04-26',
#       'fips': 45033,
#       'lat': '34.39007791',
#       'long': '-79.37741872',
#       'confirmed': 41,
#       'deaths': 0,
#       'confirmed_diff': 6,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Dorchester',
#       'date': '2020-04-26',
#       'fips': 45035,
#       'lat': '33.0794369',
#       'long': '-80.40502652',
#       'confirmed': 90,
#       'deaths': 2,
#       'confirmed_diff': 4,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Edgefield',
#       'date': '2020-04-26',
#       'fips': 45037,
#       'lat': '33.77221995',
#       'long': '-81.96231108',
#       'confirmed': 24,
#       'deaths': 1,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Fairfield',
#       'date': '2020-04-26',
#       'fips': 45039,
#       'lat': '34.39287073',
#       'long': '-81.1195624',
#       'confirmed': 33,
#       'deaths': 2,
#       'confirmed_diff': 4,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Florence',
#       'date': '2020-04-26',
#       'fips': 45041,
#       'lat': '34.02361754',
#       'long': '-79.70189312',
#       'confirmed': 265,
#       'deaths': 9,
#       'confirmed_diff': 23,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Georgetown',
#       'date': '2020-04-26',
#       'fips': 45043,
#       'lat': '33.43443342',
#       'long': '-79.33202141',
#       'confirmed': 39,
#       'deaths': 2,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Greenville',
#       'date': '2020-04-26',
#       'fips': 45045,
#       'lat': '34.89502264',
#       'long': '-82.37295012',
#       'confirmed': 609,
#       'deaths': 19,
#       'confirmed_diff': 45,
#       'deaths_diff': 3,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Greenwood',
#       'date': '2020-04-26',
#       'fips': 45047,
#       'lat': '34.15272415',
#       'long': '-82.12715789',
#       'confirmed': 44,
#       'deaths': 0,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Hampton',
#       'date': '2020-04-26',
#       'fips': 45049,
#       'lat': '32.77419582',
#       'long': '-81.13845571',
#       'confirmed': 21,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Horry',
#       'date': '2020-04-26',
#       'fips': 45051,
#       'lat': '33.9212828',
#       'long': '-78.99555293',
#       'confirmed': 203,
#       'deaths': 12,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Jasper',
#       'date': '2020-04-26',
#       'fips': 45053,
#       'lat': '32.43171982',
#       'long': '-81.02487495',
#       'confirmed': 19,
#       'deaths': 1,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Kershaw',
#       'date': '2020-04-26',
#       'fips': 45055,
#       'lat': '34.33988254',
#       'long': '-80.58763164',
#       'confirmed': 218,
#       'deaths': 10,
#       'confirmed_diff': 3,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Lancaster',
#       'date': '2020-04-26',
#       'fips': 45057,
#       'lat': '34.68270843',
#       'long': '-80.70513032',
#       'confirmed': 87,
#       'deaths': 3,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Laurens',
#       'date': '2020-04-26',
#       'fips': 45059,
#       'lat': '34.48244419',
#       'long': '-82.00490796',
#       'confirmed': 29,
#       'deaths': 1,
#       'confirmed_diff': 7,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Lee',
#       'date': '2020-04-26',
#       'fips': 45061,
#       'lat': '34.16393091',
#       'long': '-80.25690731',
#       'confirmed': 51,
#       'deaths': 6,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Lexington',
#       'date': '2020-04-26',
#       'fips': 45063,
#       'lat': '33.89665987',
#       'long': '-81.27146426',
#       'confirmed': 329,
#       'deaths': 12,
#       'confirmed_diff': 12,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Marion',
#       'date': '2020-04-26',
#       'fips': 45067,
#       'lat': '34.07859748',
#       'long': '-79.36400756',
#       'confirmed': 32,
#       'deaths': 1,
#       'confirmed_diff': 3,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Marlboro',
#       'date': '2020-04-26',
#       'fips': 45069,
#       'lat': '34.59905577',
#       'long': '-79.67561152',
#       'confirmed': 40,
#       'deaths': 0,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'McCormick',
#       'date': '2020-04-26',
#       'fips': 45065,
#       'lat': '33.90161443',
#       'long': '-82.30794338',
#       'confirmed': 6,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Newberry',
#       'date': '2020-04-26',
#       'fips': 45071,
#       'lat': '34.28629098',
#       'long': '-81.59935761',
#       'confirmed': 23,
#       'deaths': 1,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Oconee',
#       'date': '2020-04-26',
#       'fips': 45073,
#       'lat': '34.75225169',
#       'long': '-83.06742317',
#       'confirmed': 22,
#       'deaths': 0,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Orangeburg',
#       'date': '2020-04-26',
#       'fips': 45075,
#       'lat': '33.4391073',
#       'long': '-80.79886287',
#       'confirmed': 61,
#       'deaths': 1,
#       'confirmed_diff': 5,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Pickens',
#       'date': '2020-04-26',
#       'fips': 45077,
#       'lat': '34.88807695',
#       'long': '-82.72791551',
#       'confirmed': 49,
#       'deaths': 0,
#       'confirmed_diff': 5,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Richland',
#       'date': '2020-04-26',
#       'fips': 45079,
#       'lat': '34.01791263',
#       'long': '-80.90267209',
#       'confirmed': 837,
#       'deaths': 19,
#       'confirmed_diff': 50,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Saluda',
#       'date': '2020-04-26',
#       'fips': 45081,
#       'lat': '34.00795823',
#       'long': '-81.72713237',
#       'confirmed': 35,
#       'deaths': 0,
#       'confirmed_diff': 7,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Spartanburg',
#       'date': '2020-04-26',
#       'fips': 45083,
#       'lat': '34.92960077',
#       'long': '-81.99225984',
#       'confirmed': 249,
#       'deaths': 8,
#       'confirmed_diff': 6,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Sumter',
#       'date': '2020-04-26',
#       'fips': 45085,
#       'lat': '33.91826534',
#       'long': '-80.37942316',
#       'confirmed': 214,
#       'deaths': 6,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Unassigned',
#       'date': '2020-04-26',
#       'fips': 90045,
#       'lat': None,
#       'long': None,
#       'confirmed': 0,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Union',
#       'date': '2020-04-26',
#       'fips': 45087,
#       'lat': '34.68835752',
#       'long': '-81.61730349',
#       'confirmed': 25,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Williamsburg',
#       'date': '2020-04-26',
#       'fips': 45089,
#       'lat': '33.62190129',
#       'long': '-79.72767442',
#       'confirmed': 56,
#       'deaths': 0,
#       'confirmed_diff': 11,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'York',
#       'date': '2020-04-26',
#       'fips': 45091,
#       'lat': '34.97281497',
#       'long': '-81.18085944',
#       'confirmed': 181,
#       'deaths': 3,
#       'confirmed_diff': 4,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'}]}},
#   {'date': '2020-04-26',
#    'confirmed': 26773,
#    'deaths': 1729,
#    'recovered': 0,
#    'confirmed_diff': 261,
#    'deaths_diff': 22,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:52',
#    'active': 25044,
#    'active_diff': 239,
#    'fatality_rate': 0.0646,
#    'region': {'iso': 'USA',
#     'name': 'US',
#     'province': 'Louisiana',
#     'lat': '31.1695',
#     'long': '-91.8678',
#     'cities': [{'name': 'Acadia',
#       'date': '2020-04-26',
#       'fips': 22001,
#       'lat': '30.2950649',
#       'long': '-92.41419698',
#       'confirmed': 130,
#       'deaths': 7,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Allen',
#       'date': '2020-04-26',
#       'fips': 22003,
#       'lat': '30.65385745',
#       'long': '-92.82442028',
#       'confirmed': 82,
#       'deaths': 9,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Ascension',
#       'date': '2020-04-26',
#       'fips': 22005,
#       'lat': '30.20406249',
#       'long': '-90.91328409999998',
#       'confirmed': 568,
#       'deaths': 36,
#       'confirmed_diff': 11,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Assumption',
#       'date': '2020-04-26',
#       'fips': 22007,
#       'lat': '29.89946234',
#       'long': '-91.06461642',
#       'confirmed': 173,
#       'deaths': 3,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Avoyelles',
#       'date': '2020-04-26',
#       'fips': 22009,
#       'lat': '31.07796211',
#       'long': '-92.00079449',
#       'confirmed': 69,
#       'deaths': 7,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Beauregard',
#       'date': '2020-04-26',
#       'fips': 22011,
#       'lat': '30.64836518',
#       'long': '-93.34173616',
#       'confirmed': 35,
#       'deaths': 3,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Bienville',
#       'date': '2020-04-26',
#       'fips': 22013,
#       'lat': '32.34569994',
#       'long': '-93.05398492',
#       'confirmed': 72,
#       'deaths': 13,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Bossier',
#       'date': '2020-04-26',
#       'fips': 22015,
#       'lat': '32.67932307',
#       'long': '-93.60460152',
#       'confirmed': 270,
#       'deaths': 13,
#       'confirmed_diff': 5,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Caddo',
#       'date': '2020-04-26',
#       'fips': 22017,
#       'lat': '32.57991587',
#       'long': '-93.88375652',
#       'confirmed': 1448,
#       'deaths': 93,
#       'confirmed_diff': 16,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Calcasieu',
#       'date': '2020-04-26',
#       'fips': 22019,
#       'lat': '30.22931235',
#       'long': '-93.35400434',
#       'confirmed': 363,
#       'deaths': 27,
#       'confirmed_diff': 3,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Caldwell',
#       'date': '2020-04-26',
#       'fips': 22021,
#       'lat': '32.0902519',
#       'long': '-92.11752148',
#       'confirmed': 17,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Cameron',
#       'date': '2020-04-26',
#       'fips': 22023,
#       'lat': '29.87592238',
#       'long': '-93.19310676',
#       'confirmed': 3,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Catahoula',
#       'date': '2020-04-26',
#       'fips': 22025,
#       'lat': '31.66778967',
#       'long': '-91.84526385',
#       'confirmed': 25,
#       'deaths': 2,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Claiborne',
#       'date': '2020-04-26',
#       'fips': 22027,
#       'lat': '32.82308512',
#       'long': '-92.99526883',
#       'confirmed': 52,
#       'deaths': 6,
#       'confirmed_diff': 0,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Concordia',
#       'date': '2020-04-26',
#       'fips': 22029,
#       'lat': '31.44817835',
#       'long': '-91.63814433',
#       'confirmed': 30,
#       'deaths': 3,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'De Soto',
#       'date': '2020-04-26',
#       'fips': 22031,
#       'lat': '32.05457447',
#       'long': '-93.74130302',
#       'confirmed': 185,
#       'deaths': 10,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'East Baton Rouge',
#       'date': '2020-04-26',
#       'fips': 22033,
#       'lat': '30.53842039',
#       'long': '-91.09777565',
#       'confirmed': 1739,
#       'deaths': 120,
#       'confirmed_diff': 19,
#       'deaths_diff': 6,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'East Carroll',
#       'date': '2020-04-26',
#       'fips': 22035,
#       'lat': '32.73926954',
#       'long': '-91.23425694',
#       'confirmed': 6,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'East Feliciana',
#       'date': '2020-04-26',
#       'fips': 22037,
#       'lat': '30.84425359',
#       'long': '-91.04976723',
#       'confirmed': 108,
#       'deaths': 11,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Evangeline',
#       'date': '2020-04-26',
#       'fips': 22039,
#       'lat': '30.72985248',
#       'long': '-92.39915924',
#       'confirmed': 45,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Franklin',
#       'date': '2020-04-26',
#       'fips': 22041,
#       'lat': '32.13675181',
#       'long': '-91.67589857',
#       'confirmed': 116,
#       'deaths': 2,
#       'confirmed_diff': 3,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Grant',
#       'date': '2020-04-26',
#       'fips': 22043,
#       'lat': '31.59882456',
#       'long': '-92.56124347',
#       'confirmed': 11,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Iberia',
#       'date': '2020-04-26',
#       'fips': 22045,
#       'lat': '29.86803617',
#       'long': '-91.75871777',
#       'confirmed': 243,
#       'deaths': 16,
#       'confirmed_diff': 3,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Iberville',
#       'date': '2020-04-26',
#       'fips': 22047,
#       'lat': '30.25734305',
#       'long': '-91.3499598',
#       'confirmed': 433,
#       'deaths': 26,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Jackson',
#       'date': '2020-04-26',
#       'fips': 22049,
#       'lat': '32.30251776',
#       'long': '-92.55692092',
#       'confirmed': 25,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Jefferson',
#       'date': '2020-04-26',
#       'fips': 22051,
#       'lat': '29.74075478',
#       'long': '-90.11115756',
#       'confirmed': 6059,
#       'deaths': 329,
#       'confirmed_diff': 52,
#       'deaths_diff': 4,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Jefferson Davis',
#       'date': '2020-04-26',
#       'fips': 22053,
#       'lat': '30.26896765',
#       'long': '-92.81210004',
#       'confirmed': 59,
#       'deaths': 5,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'LaSalle',
#       'date': '2020-04-26',
#       'fips': 22059,
#       'lat': '31.67884782',
#       'long': '-92.15907765',
#       'confirmed': 19,
#       'deaths': 0,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Lafayette',
#       'date': '2020-04-26',
#       'fips': 22055,
#       'lat': '30.2049055',
#       'long': '-92.06959876',
#       'confirmed': 443,
#       'deaths': 17,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Lafourche',
#       'date': '2020-04-26',
#       'fips': 22057,
#       'lat': '29.52470226',
#       'long': '-90.40976986',
#       'confirmed': 624,
#       'deaths': 39,
#       'confirmed_diff': 14,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Lincoln',
#       'date': '2020-04-26',
#       'fips': 22061,
#       'lat': '32.6003154',
#       'long': '-92.6659741',
#       'confirmed': 72,
#       'deaths': 4,
#       'confirmed_diff': 3,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Livingston',
#       'date': '2020-04-26',
#       'fips': 22063,
#       'lat': '30.44143993',
#       'long': '-90.73061664',
#       'confirmed': 182,
#       'deaths': 11,
#       'confirmed_diff': 5,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Madison',
#       'date': '2020-04-26',
#       'fips': 22065,
#       'lat': '32.36918118',
#       'long': '-91.23973355',
#       'confirmed': 7,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Morehouse',
#       'date': '2020-04-26',
#       'fips': 22067,
#       'lat': '32.81686191',
#       'long': '-91.80421614',
#       'confirmed': 46,
#       'deaths': 4,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Natchitoches',
#       'date': '2020-04-26',
#       'fips': 22069,
#       'lat': '31.72321584',
#       'long': '-93.09816516',
#       'confirmed': 73,
#       'deaths': 2,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Orleans',
#       'date': '2020-04-26',
#       'fips': 22071,
#       'lat': '30.06971951',
#       'long': '-89.92660315',
#       'confirmed': 6342,
#       'deaths': 406,
#       'confirmed_diff': 45,
#       'deaths_diff': 7,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Ouachita',
#       'date': '2020-04-26',
#       'fips': 22073,
#       'lat': '32.47645559',
#       'long': '-92.15704172',
#       'confirmed': 622,
#       'deaths': 16,
#       'confirmed_diff': 13,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Plaquemines',
#       'date': '2020-04-26',
#       'fips': 22075,
#       'lat': '29.42245447',
#       'long': '-89.60322085',
#       'confirmed': 168,
#       'deaths': 15,
#       'confirmed_diff': 0,
#       'deaths_diff': -1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Pointe Coupee',
#       'date': '2020-04-26',
#       'fips': 22077,
#       'lat': '30.71409502',
#       'long': '-91.60209535',
#       'confirmed': 89,
#       'deaths': 12,
#       'confirmed_diff': 0,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Rapides',
#       'date': '2020-04-26',
#       'fips': 22079,
#       'lat': '31.19778499',
#       'long': '-92.52997303',
#       'confirmed': 247,
#       'deaths': 8,
#       'confirmed_diff': 8,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Red River',
#       'date': '2020-04-26',
#       'fips': 22081,
#       'lat': '32.09530039',
#       'long': '-93.34213308',
#       'confirmed': 22,
#       'deaths': 4,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Richland',
#       'date': '2020-04-26',
#       'fips': 22083,
#       'lat': '32.41391005',
#       'long': '-91.76634876',
#       'confirmed': 48,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Sabine',
#       'date': '2020-04-26',
#       'fips': 22085,
#       'lat': '31.56388699',
#       'long': '-93.55433981',
#       'confirmed': 13,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'St. Bernard',
#       'date': '2020-04-26',
#       'fips': 22087,
#       'lat': '29.87761636',
#       'long': '-89.51887093',
#       'confirmed': 446,
#       'deaths': 15,
#       'confirmed_diff': 3,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'St. Charles',
#       'date': '2020-04-26',
#       'fips': 22089,
#       'lat': '29.90709658',
#       'long': '-90.35555967',
#       'confirmed': 542,
#       'deaths': 36,
#       'confirmed_diff': 2,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'St. Helena',
#       'date': '2020-04-26',
#       'fips': 22091,
#       'lat': '30.82210324',
#       'long': '-90.71013176',
#       'confirmed': 27,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'St. James',
#       'date': '2020-04-26',
#       'fips': 22093,
#       'lat': '30.02531716',
#       'long': '-90.80212061',
#       'confirmed': 239,
#       'deaths': 18,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'St. John the Baptist',
#       'date': '2020-04-26',
#       'fips': 22095,
#       'lat': '30.12597499',
#       'long': '-90.4753503',
#       'confirmed': 749,
#       'deaths': 64,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'St. Landry',
#       'date': '2020-04-26',
#       'fips': 22097,
#       'lat': '30.59724262',
#       'long': '-92.00135806',
#       'confirmed': 163,
#       'deaths': 34,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'St. Martin',
#       'date': '2020-04-26',
#       'fips': 22099,
#       'lat': '30.13112107',
#       'long': '-91.61403569',
#       'confirmed': 221,
#       'deaths': 15,
#       'confirmed_diff': 2,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'St. Mary',
#       'date': '2020-04-26',
#       'fips': 22101,
#       'lat': '29.69262097',
#       'long': '-91.44702164',
#       'confirmed': 179,
#       'deaths': 20,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'St. Tammany',
#       'date': '2020-04-26',
#       'fips': 22103,
#       'lat': '30.40942847',
#       'long': '-89.95642711',
#       'confirmed': 1162,
#       'deaths': 94,
#       'confirmed_diff': 24,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Tangipahoa',
#       'date': '2020-04-26',
#       'fips': 22105,
#       'lat': '30.62888673',
#       'long': '-90.40664996',
#       'confirmed': 528,
#       'deaths': 21,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Tensas',
#       'date': '2020-04-26',
#       'fips': 22107,
#       'lat': '32.00760749',
#       'long': '-91.32915234',
#       'confirmed': 1,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Terrebonne',
#       'date': '2020-04-26',
#       'fips': 22109,
#       'lat': '29.37343766',
#       'long': '-90.82626855',
#       'confirmed': 371,
#       'deaths': 26,
#       'confirmed_diff': 5,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Unassigned',
#       'date': '2020-04-26',
#       'fips': 90022,
#       'lat': None,
#       'long': None,
#       'confirmed': 64,
#       'deaths': 59,
#       'confirmed_diff': 1,
#       'deaths_diff': -4,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Union',
#       'date': '2020-04-26',
#       'fips': 22111,
#       'lat': '32.83121059',
#       'long': '-92.3749373',
#       'confirmed': 102,
#       'deaths': 6,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Vermilion',
#       'date': '2020-04-26',
#       'fips': 22113,
#       'lat': '29.83517605',
#       'long': '-92.30292538',
#       'confirmed': 34,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Vernon',
#       'date': '2020-04-26',
#       'fips': 22115,
#       'lat': '31.10884837',
#       'long': '-93.18153838',
#       'confirmed': 16,
#       'deaths': 2,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Washington',
#       'date': '2020-04-26',
#       'fips': 22117,
#       'lat': '30.85288548',
#       'long': '-90.03866652',
#       'confirmed': 245,
#       'deaths': 14,
#       'confirmed_diff': 4,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Webster',
#       'date': '2020-04-26',
#       'fips': 22119,
#       'lat': '32.70847669',
#       'long': '-93.33121835',
#       'confirmed': 83,
#       'deaths': 4,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'West Baton Rouge',
#       'date': '2020-04-26',
#       'fips': 22121,
#       'lat': '30.46058217',
#       'long': '-91.30989571',
#       'confirmed': 91,
#       'deaths': 15,
#       'confirmed_diff': -1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'West Carroll',
#       'date': '2020-04-26',
#       'fips': 22123,
#       'lat': '32.78550125',
#       'long': '-91.461201',
#       'confirmed': 4,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'West Feliciana',
#       'date': '2020-04-26',
#       'fips': 22125,
#       'lat': '30.87882871',
#       'long': '-91.4148538',
#       'confirmed': 103,
#       'deaths': 3,
#       'confirmed_diff': 6,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Winn',
#       'date': '2020-04-26',
#       'fips': 22127,
#       'lat': '31.94449367',
#       'long': '-92.63789413',
#       'confirmed': 20,
#       'deaths': 2,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'}]}},
#   {'date': '2020-04-26',
#    'confirmed': 12970,
#    'deaths': 449,
#    'recovered': 0,
#    'confirmed_diff': 604,
#    'deaths_diff': 12,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:52',
#    'active': 12521,
#    'active_diff': 592,
#    'fatality_rate': 0.0346,
#    'region': {'iso': 'USA',
#     'name': 'US',
#     'province': 'Virginia',
#     'lat': '37.7693',
#     'long': '-78.1700',
#     'cities': [{'name': 'Accomack',
#       'date': '2020-04-26',
#       'fips': 51001,
#       'lat': '37.76707161',
#       'long': '-75.63234615',
#       'confirmed': 187,
#       'deaths': 3,
#       'confirmed_diff': 41,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Albemarle',
#       'date': '2020-04-26',
#       'fips': 51003,
#       'lat': '38.02080697',
#       'long': '-78.55481085',
#       'confirmed': 76,
#       'deaths': 3,
#       'confirmed_diff': 3,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Alexandria',
#       'date': '2020-04-26',
#       'fips': 51510,
#       'lat': '38.814003',
#       'long': '-77.08183073',
#       'confirmed': 591,
#       'deaths': 19,
#       'confirmed_diff': 16,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Alleghany',
#       'date': '2020-04-26',
#       'fips': 51005,
#       'lat': '37.78636074',
#       'long': '-80.00222498',
#       'confirmed': 5,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Amelia',
#       'date': '2020-04-26',
#       'fips': 51007,
#       'lat': '37.34081025',
#       'long': '-77.98584649',
#       'confirmed': 15,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Amherst',
#       'date': '2020-04-26',
#       'fips': 51009,
#       'lat': '37.60308293',
#       'long': '-79.14548696',
#       'confirmed': 9,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Appomattox',
#       'date': '2020-04-26',
#       'fips': 51011,
#       'lat': '37.37569884',
#       'long': '-78.81340003',
#       'confirmed': 17,
#       'deaths': 0,
#       'confirmed_diff': 5,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Arlington',
#       'date': '2020-04-26',
#       'fips': 51013,
#       'lat': '38.8767675',
#       'long': '-77.10139853',
#       'confirmed': 790,
#       'deaths': 32,
#       'confirmed_diff': 26,
#       'deaths_diff': 3,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Augusta',
#       'date': '2020-04-26',
#       'fips': 51015,
#       'lat': '38.16404586',
#       'long': '-79.12461614',
#       'confirmed': 36,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Bath',
#       'date': '2020-04-26',
#       'fips': 51017,
#       'lat': '38.05852573',
#       'long': '-79.73912095',
#       'confirmed': 0,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Bedford',
#       'date': '2020-04-26',
#       'fips': 51019,
#       'lat': '37.3080028',
#       'long': '-79.5281964',
#       'confirmed': 24,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Bland',
#       'date': '2020-04-26',
#       'fips': 51021,
#       'lat': '37.13128068',
#       'long': '-81.13599391',
#       'confirmed': 0,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Botetourt',
#       'date': '2020-04-26',
#       'fips': 51023,
#       'lat': '37.55531756',
#       'long': '-79.80982182',
#       'confirmed': 27,
#       'deaths': 3,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Bristol',
#       'date': '2020-04-26',
#       'fips': 51520,
#       'lat': '36.6163024',
#       'long': '-82.16359122',
#       'confirmed': 1,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Brunswick',
#       'date': '2020-04-26',
#       'fips': 51025,
#       'lat': '36.76366949',
#       'long': '-77.8593436',
#       'confirmed': 14,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Buchanan',
#       'date': '2020-04-26',
#       'fips': 51027,
#       'lat': '37.26818323',
#       'long': '-82.03749726',
#       'confirmed': 13,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Buckingham',
#       'date': '2020-04-26',
#       'fips': 51029,
#       'lat': '37.57242268',
#       'long': '-78.52518834',
#       'confirmed': 35,
#       'deaths': 0,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Buena Vista',
#       'date': '2020-04-26',
#       'fips': 51530,
#       'lat': '37.73484642',
#       'long': '-79.35296097',
#       'confirmed': 5,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Campbell',
#       'date': '2020-04-26',
#       'fips': 51031,
#       'lat': '37.20553386',
#       'long': '-79.09678609',
#       'confirmed': 11,
#       'deaths': 0,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Caroline',
#       'date': '2020-04-26',
#       'fips': 51033,
#       'lat': '38.02679129',
#       'long': '-77.34901405',
#       'confirmed': 21,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Carroll',
#       'date': '2020-04-26',
#       'fips': 51035,
#       'lat': '36.73066666',
#       'long': '-80.73455942',
#       'confirmed': 3,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Charles City',
#       'date': '2020-04-26',
#       'fips': 51036,
#       'lat': '37.35358063',
#       'long': '-77.05634116',
#       'confirmed': 13,
#       'deaths': 1,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Charlotte',
#       'date': '2020-04-26',
#       'fips': 51037,
#       'lat': '37.01909701',
#       'long': '-78.66314092',
#       'confirmed': 7,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Charlottesville',
#       'date': '2020-04-26',
#       'fips': 51540,
#       'lat': '38.03527919',
#       'long': '-78.48569588',
#       'confirmed': 49,
#       'deaths': 2,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Chesapeake',
#       'date': '2020-04-26',
#       'fips': 51550,
#       'lat': '36.67670048',
#       'long': '-76.30545744',
#       'confirmed': 208,
#       'deaths': 6,
#       'confirmed_diff': 8,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Chesterfield',
#       'date': '2020-04-26',
#       'fips': 51041,
#       'lat': '37.37373208',
#       'long': '-77.58680140000001',
#       'confirmed': 457,
#       'deaths': 18,
#       'confirmed_diff': 17,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Clarke',
#       'date': '2020-04-26',
#       'fips': 51043,
#       'lat': '39.11271747',
#       'long': '-77.99199425',
#       'confirmed': 7,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Colonial Heights',
#       'date': '2020-04-26',
#       'fips': 51570,
#       'lat': '37.26420587',
#       'long': '-77.39609676',
#       'confirmed': 45,
#       'deaths': 3,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Covington',
#       'date': '2020-04-26',
#       'fips': 51580,
#       'lat': '37.7824656',
#       'long': '-79.98631446',
#       'confirmed': 1,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Craig',
#       'date': '2020-04-26',
#       'fips': 51045,
#       'lat': '37.48133648',
#       'long': '-80.21072274',
#       'confirmed': 2,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Culpeper',
#       'date': '2020-04-26',
#       'fips': 51047,
#       'lat': '38.48199985',
#       'long': '-77.95630870000002',
#       'confirmed': 103,
#       'deaths': 1,
#       'confirmed_diff': 8,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Cumberland',
#       'date': '2020-04-26',
#       'fips': 51049,
#       'lat': '37.51328851',
#       'long': '-78.24398086',
#       'confirmed': 10,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Danville',
#       'date': '2020-04-26',
#       'fips': 51590,
#       'lat': '36.58022376',
#       'long': '-79.40395668',
#       'confirmed': 33,
#       'deaths': 1,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Dickenson',
#       'date': '2020-04-26',
#       'fips': 51051,
#       'lat': '37.12560977',
#       'long': '-82.35124171',
#       'confirmed': 0,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Dinwiddie',
#       'date': '2020-04-26',
#       'fips': 51053,
#       'lat': '37.07544585',
#       'long': '-77.63451754',
#       'confirmed': 14,
#       'deaths': 0,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Emporia',
#       'date': '2020-04-26',
#       'fips': 51595,
#       'lat': '36.69455571',
#       'long': '-77.53406129',
#       'confirmed': 18,
#       'deaths': 2,
#       'confirmed_diff': 0,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Essex',
#       'date': '2020-04-26',
#       'fips': 51057,
#       'lat': '37.93357639',
#       'long': '-76.94230311',
#       'confirmed': 6,
#       'deaths': 0,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Fairfax',
#       'date': '2020-04-26',
#       'fips': 51059,
#       'lat': '38.83677558',
#       'long': '-77.27565836',
#       'confirmed': 2889,
#       'deaths': 95,
#       'confirmed_diff': 144,
#       'deaths_diff': 5,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Fairfax City',
#       'date': '2020-04-26',
#       'fips': 51600,
#       'lat': '38.85157547',
#       'long': '-77.29779640000002',
#       'confirmed': 26,
#       'deaths': 2,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Falls Church',
#       'date': '2020-04-26',
#       'fips': 51610,
#       'lat': '38.88485255',
#       'long': '-77.17560759',
#       'confirmed': 26,
#       'deaths': 2,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Fauquier',
#       'date': '2020-04-26',
#       'fips': 51061,
#       'lat': '38.73564842',
#       'long': '-77.80647472',
#       'confirmed': 87,
#       'deaths': 2,
#       'confirmed_diff': 7,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Floyd',
#       'date': '2020-04-26',
#       'fips': 51063,
#       'lat': '36.9302126',
#       'long': '-80.36738849',
#       'confirmed': 1,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Fluvanna',
#       'date': '2020-04-26',
#       'fips': 51065,
#       'lat': '37.84157909',
#       'long': '-78.27715475',
#       'confirmed': 72,
#       'deaths': 5,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Franklin',
#       'date': '2020-04-26',
#       'fips': 51067,
#       'lat': '36.99536167',
#       'long': '-79.88023649',
#       'confirmed': 19,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Franklin City',
#       'date': '2020-04-26',
#       'fips': 51620,
#       'lat': '36.6831435',
#       'long': '-76.93859681',
#       'confirmed': 16,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Frederick',
#       'date': '2020-04-26',
#       'fips': 51069,
#       'lat': '39.20172582',
#       'long': '-78.25974949',
#       'confirmed': 93,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Fredericksburg',
#       'date': '2020-04-26',
#       'fips': 51630,
#       'lat': '38.2977863',
#       'long': '-77.4922454',
#       'confirmed': 23,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Galax',
#       'date': '2020-04-26',
#       'fips': 51640,
#       'lat': '36.66601852',
#       'long': '-80.91703124',
#       'confirmed': 4,
#       'deaths': 0,
#       'confirmed_diff': 3,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Giles',
#       'date': '2020-04-26',
#       'fips': 51071,
#       'lat': '37.31234791',
#       'long': '-80.70636931',
#       'confirmed': 4,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Gloucester',
#       'date': '2020-04-26',
#       'fips': 51073,
#       'lat': '37.40809042',
#       'long': '-76.53524337',
#       'confirmed': 22,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Goochland',
#       'date': '2020-04-26',
#       'fips': 51075,
#       'lat': '37.71714806',
#       'long': '-77.90381514',
#       'confirmed': 70,
#       'deaths': 3,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Grayson',
#       'date': '2020-04-26',
#       'fips': 51077,
#       'lat': '36.65677234',
#       'long': '-81.23215889',
#       'confirmed': 0,
#       'deaths': 0,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Greene',
#       'date': '2020-04-26',
#       'fips': 51079,
#       'lat': '38.29545894',
#       'long': '-78.46525378',
#       'confirmed': 10,
#       'deaths': 1,
#       'confirmed_diff': 0,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Greensville',
#       'date': '2020-04-26',
#       'fips': 51081,
#       'lat': '36.67878901',
#       'long': '-77.56351439',
#       'confirmed': 30,
#       'deaths': 5,
#       'confirmed_diff': 0,
#       'deaths_diff': 1,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Halifax',
#       'date': '2020-04-26',
#       'fips': 51083,
#       'lat': '36.76654925',
#       'long': '-78.93512622',
#       'confirmed': 17,
#       'deaths': 0,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Hampton',
#       'date': '2020-04-26',
#       'fips': 51650,
#       'lat': '37.03513786',
#       'long': '-76.35879121',
#       'confirmed': 104,
#       'deaths': 1,
#       'confirmed_diff': 3,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Hanover',
#       'date': '2020-04-26',
#       'fips': 51085,
#       'lat': '37.7583355',
#       'long': '-77.49464673',
#       'confirmed': 105,
#       'deaths': 7,
#       'confirmed_diff': 2,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Harrisonburg',
#       'date': '2020-04-26',
#       'fips': 51660,
#       'lat': '38.43542574',
#       'long': '-78.87536254',
#       'confirmed': 371,
#       'deaths': 9,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Henrico',
#       'date': '2020-04-26',
#       'fips': 51087,
#       'lat': '37.53460572',
#       'long': '-77.39326555',
#       'confirmed': 792,
#       'deaths': 89,
#       'confirmed_diff': 28,
#       'deaths_diff': 0,
#       'last_update': '2020-04-27 02:30:52'},
#      {'name': 'Henry',
#       'date': '2020-04-26',
#       'fips': 51089,
#       'lat': '36.68542395',
#       'long': '-79.87634026',
#       'confirmed': 14,
#       'deaths': 1,
#       'confirmed_diff': 1,
#       'deaths_diff': 0,
# ...
#    'active': 1093,
#    'active_diff': 5,
#    'fatality_rate': 0.0587,
#    'region': {'iso': 'SVN',
#     'name': 'Slovenia',
#     'province': '',
#     'lat': '46.1512',
#     'long': '14.9955',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 436,
#    'deaths': 23,
#    'recovered': 10,
#    'confirmed_diff': 46,
#    'deaths_diff': 5,
#    'recovered_diff': 2,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 403,
#    'active_diff': 39,
#    'fatality_rate': 0.0528,
#    'region': {'iso': 'SOM',
#     'name': 'Somalia',
#     'province': '',
#     'lat': '5.1521',
#     'long': '46.1996',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 4546,
#    'deaths': 87,
#    'recovered': 1473,
#    'confirmed_diff': 185,
#    'deaths_diff': 1,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 2986,
#    'active_diff': 184,
#    'fatality_rate': 0.0191,
#    'region': {'iso': 'ZAF',
#     'name': 'South Africa',
#     'province': '',
#     'lat': '-30.5595',
#     'long': '22.9375',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 6,
#    'deaths': 0,
#    'recovered': 0,
#    'confirmed_diff': 1,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 6,
#    'active_diff': 1,
#    'fatality_rate': 0,
#    'region': {'iso': 'SSD',
#     'name': 'South Sudan',
#     'province': '',
#     'lat': '6.8770000000000024',
#     'long': '31.307',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 226629,
#    'deaths': 23190,
#    'recovered': 117727,
#    'confirmed_diff': 2870,
#    'deaths_diff': 288,
#    'recovered_diff': 22019,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 85712,
#    'active_diff': -19437,
#    'fatality_rate': 0.1023,
#    'region': {'iso': 'ESP',
#     'name': 'Spain',
#     'province': '',
#     'lat': '40.4637',
#     'long': '-3.7492',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 523,
#    'deaths': 7,
#    'recovered': 120,
#    'confirmed_diff': 63,
#    'deaths_diff': 0,
#    'recovered_diff': 2,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 396,
#    'active_diff': 61,
#    'fatality_rate': 0.0134,
#    'region': {'iso': 'LKA',
#     'name': 'Sri Lanka',
#     'province': '',
#     'lat': '7.8731',
#     'long': '80.7718',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 237,
#    'deaths': 21,
#    'recovered': 20,
#    'confirmed_diff': 24,
#    'deaths_diff': 4,
#    'recovered_diff': 1,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 196,
#    'active_diff': 19,
#    'fatality_rate': 0.0886,
#    'region': {'iso': 'SDN',
#     'name': 'Sudan',
#     'province': '',
#     'lat': '12.8628',
#     'long': '30.2176',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 10,
#    'deaths': 1,
#    'recovered': 7,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 2,
#    'active_diff': 0,
#    'fatality_rate': 0.1,
#    'region': {'iso': 'SUR',
#     'name': 'Suriname',
#     'province': '',
#     'lat': '3.9193',
#     'long': '-56.0278',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 18640,
#    'deaths': 2194,
#    'recovered': 1005,
#    'confirmed_diff': 463,
#    'deaths_diff': 2,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 15441,
#    'active_diff': 461,
#    'fatality_rate': 0.1177,
#    'region': {'iso': 'SWE',
#     'name': 'Sweden',
#     'province': '',
#     'lat': '60.1282',
#     'long': '18.6435',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 29061,
#    'deaths': 1610,
#    'recovered': 21800,
#    'confirmed_diff': 167,
#    'deaths_diff': 11,
#    'recovered_diff': 500,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 5651,
#    'active_diff': -344,
#    'fatality_rate': 0.0554,
#    'region': {'iso': 'CHE',
#     'name': 'Switzerland',
#     'province': '',
#     'lat': '46.8182',
#     'long': '8.2275',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 43,
#    'deaths': 3,
#    'recovered': 14,
#    'confirmed_diff': 1,
#    'deaths_diff': 0,
#    'recovered_diff': 3,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 26,
#    'active_diff': -2,
#    'fatality_rate': 0.0698,
#    'region': {'iso': 'SYR',
#     'name': 'Syria',
#     'province': '',
#     'lat': '34.8021',
#     'long': '38.9968',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 429,
#    'deaths': 6,
#    'recovered': 281,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 6,
#    'last_update': '2020-04-26 10:31:22',
#    'active': 142,
#    'active_diff': -6,
#    'fatality_rate': 0.014,
#    'region': {'iso': 'TWN',
#     'name': 'Taiwan*',
#     'province': '',
#     'lat': '23.7000',
#     'long': '121.0000',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 299,
#    'deaths': 10,
#    'recovered': 48,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 241,
#    'active_diff': 0,
#    'fatality_rate': 0.0334,
#    'region': {'iso': 'TZA',
#     'name': 'Tanzania',
#     'province': '',
#     'lat': '-6.3690',
#     'long': '34.8888',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 2922,
#    'deaths': 51,
#    'recovered': 2594,
#    'confirmed_diff': 15,
#    'deaths_diff': 0,
#    'recovered_diff': 47,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 277,
#    'active_diff': -32,
#    'fatality_rate': 0.0175,
#    'region': {'iso': 'THA',
#     'name': 'Thailand',
#     'province': '',
#     'lat': '15.8700',
#     'long': '100.9925',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 24,
#    'deaths': 0,
#    'recovered': 2,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 22,
#    'active_diff': 0,
#    'fatality_rate': 0,
#    'region': {'iso': 'TLS',
#     'name': 'Timor-Leste',
#     'province': '',
#     'lat': '-8.5500',
#     'long': '125.5600',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 98,
#    'deaths': 6,
#    'recovered': 62,
#    'confirmed_diff': 2,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 30,
#    'active_diff': 2,
#    'fatality_rate': 0.0612,
#    'region': {'iso': 'TGO',
#     'name': 'Togo',
#     'province': '',
#     'lat': '8.6195',
#     'long': '0.8248',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 115,
#    'deaths': 8,
#    'recovered': 54,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 1,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 53,
#    'active_diff': -1,
#    'fatality_rate': 0.0696,
#    'region': {'iso': 'TTO',
#     'name': 'Trinidad and Tobago',
#     'province': '',
#     'lat': '10.6918',
#     'long': '-61.2225',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 949,
#    'deaths': 38,
#    'recovered': 216,
#    'confirmed_diff': 10,
#    'deaths_diff': 0,
#    'recovered_diff': 9,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 695,
#    'active_diff': 1,
#    'fatality_rate': 0.04,
#    'region': {'iso': 'TUN',
#     'name': 'Tunisia',
#     'province': '',
#     'lat': '33.8869',
#     'long': '9.5375',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 110130,
#    'deaths': 2805,
#    'recovered': 29140,
#    'confirmed_diff': 2357,
#    'deaths_diff': 99,
#    'recovered_diff': 3558,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 78185,
#    'active_diff': -1300,
#    'fatality_rate': 0.0255,
#    'region': {'iso': 'TUR',
#     'name': 'Turkey',
#     'province': '',
#     'lat': '38.9637',
#     'long': '35.2433',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 79,
#    'deaths': 0,
#    'recovered': 46,
#    'confirmed_diff': 4,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 33,
#    'active_diff': 4,
#    'fatality_rate': 0,
#    'region': {'iso': 'UGA',
#     'name': 'Uganda',
#     'province': '',
#     'lat': '1.3733',
#     'long': '32.2903',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 8617,
#    'deaths': 209,
#    'recovered': 840,
#    'confirmed_diff': 492,
#    'deaths_diff': 8,
#    'recovered_diff': 58,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 7568,
#    'active_diff': 426,
#    'fatality_rate': 0.0243,
#    'region': {'iso': 'UKR',
#     'name': 'Ukraine',
#     'province': '',
#     'lat': '48.3794',
#     'long': '31.1656',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 10349,
#    'deaths': 76,
#    'recovered': 1978,
#    'confirmed_diff': 536,
#    'deaths_diff': 5,
#    'recovered_diff': 91,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 8295,
#    'active_diff': 440,
#    'fatality_rate': 0.0073,
#    'region': {'iso': 'ARE',
#     'name': 'United Arab Emirates',
#     'province': '',
#     'lat': '23.4241',
#     'long': '53.8478',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 152840,
#    'deaths': 20732,
#    'recovered': 0,
#    'confirmed_diff': 4463,
#    'deaths_diff': 413,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 132108,
#    'active_diff': 4050,
#    'fatality_rate': 0.1356,
#    'region': {'iso': 'GBR',
#     'name': 'United Kingdom',
#     'province': '',
#     'lat': '55.0000',
#     'long': '-3.0000',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 606,
#    'deaths': 15,
#    'recovered': 375,
#    'confirmed_diff': 10,
#    'deaths_diff': 1,
#    'recovered_diff': 5,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 216,
#    'active_diff': 4,
#    'fatality_rate': 0.0248,
#    'region': {'iso': 'URY',
#     'name': 'Uruguay',
#     'province': '',
#     'lat': '-32.5228',
#     'long': '-55.7658',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 1869,
#    'deaths': 8,
#    'recovered': 789,
#    'confirmed_diff': 7,
#    'deaths_diff': 0,
#    'recovered_diff': 82,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 1072,
#    'active_diff': -75,
#    'fatality_rate': 0.0043,
#    'region': {'iso': 'UZB',
#     'name': 'Uzbekistan',
#     'province': '',
#     'lat': '41.3775',
#     'long': '64.5853',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 325,
#    'deaths': 10,
#    'recovered': 137,
#    'confirmed_diff': 2,
#    'deaths_diff': 0,
#    'recovered_diff': 5,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 178,
#    'active_diff': -3,
#    'fatality_rate': 0.0308,
#    'region': {'iso': 'VEN',
#     'name': 'Venezuela',
#     'province': '',
#     'lat': '6.4238',
#     'long': '-66.5897',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 270,
#    'deaths': 0,
#    'recovered': 225,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 45,
#    'active_diff': 0,
#    'fatality_rate': 0,
#    'region': {'iso': 'VNM',
#     'name': 'Vietnam',
#     'province': '',
#     'lat': '14.0583',
#     'long': '108.2772',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 342,
#    'deaths': 2,
#    'recovered': 83,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': -9,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 257,
#    'active_diff': 9,
#    'fatality_rate': 0.0058,
#    'region': {'iso': 'PSE',
#     'name': 'West Bank and Gaza',
#     'province': '',
#     'lat': '31.9522',
#     'long': '35.2332',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 6,
#    'deaths': 0,
#    'recovered': 5,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 1,
#    'active_diff': 0,
#    'fatality_rate': 0,
#    'region': {'iso': 'ESH',
#     'name': 'Western Sahara',
#     'province': '',
#     'lat': '24.2155',
#     'long': '-12.8858',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 0,
#    'active_diff': 0,
#    'fatality_rate': 0,
#    'region': {'iso': 'YEM',
#     'name': 'Yemen',
#     'province': '',
#     'lat': '15.552726999999999',
#     'long': '48.516388',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 88,
#    'deaths': 3,
#    'recovered': 42,
#    'confirmed_diff': 4,
#    'deaths_diff': 0,
#    'recovered_diff': 5,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 43,
#    'active_diff': -1,
#    'fatality_rate': 0.0341,
#    'region': {'iso': 'ZMB',
#     'name': 'Zambia',
#     'province': '',
#     'lat': '-13.1339',
#     'long': '27.8493',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 31,
#    'deaths': 4,
#    'recovered': 2,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 0,
#    'last_update': '2020-04-27 02:30:33',
#    'active': 25,
#    'active_diff': 0,
#    'fatality_rate': 0.129,
#    'region': {'iso': 'ZWE',
#     'name': 'Zimbabwe',
#     'province': '',
#     'lat': '-19.0154',
#     'long': '29.1549',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 106,
#    'deaths': 3,
#    'recovered': 99,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 1,
#    'last_update': '2020-04-27 02:31:20',
#    'active': 4,
#    'active_diff': -1,
#    'fatality_rate': 0.0283,
#    'region': {'iso': 'AUS',
#     'name': 'Australia',
#     'province': 'Australian Capital Territory',
#     'lat': '-35.4735',
#     'long': '149.0124',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 3002,
#    'deaths': 34,
#    'recovered': 2208,
#    'confirmed_diff': 8,
#    'deaths_diff': 1,
#    'recovered_diff': 15,
#    'last_update': '2020-04-27 02:31:20',
#    'active': 760,
#    'active_diff': -8,
#    'fatality_rate': 0.0113,
#    'region': {'iso': 'AUS',
#     'name': 'Australia',
#     'province': 'New South Wales',
#     'lat': '-33.8688',
#     'long': '151.2093',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 28,
#    'deaths': 0,
#    'recovered': 23,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 23,
#    'last_update': '2020-04-27 02:31:20',
#    'active': 5,
#    'active_diff': -23,
#    'fatality_rate': 0,
#    'region': {'iso': 'AUS',
#     'name': 'Australia',
#     'province': 'Northern Territory',
#     'lat': '-12.4634',
#     'long': '130.8456',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 1030,
#    'deaths': 6,
#    'recovered': 926,
#    'confirmed_diff': 4,
#    'deaths_diff': 0,
#    'recovered_diff': 123,
#    'last_update': '2020-04-27 02:31:20',
#    'active': 98,
#    'active_diff': -119,
#    'fatality_rate': 0.0058,
#    'region': {'iso': 'AUS',
#     'name': 'Australia',
#     'province': 'Queensland',
#     'lat': '-28.0167',
#     'long': '153.4000',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 438,
#    'deaths': 4,
#    'recovered': 411,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 10,
#    'last_update': '2020-04-27 02:31:20',
#    'active': 23,
#    'active_diff': -10,
#    'fatality_rate': 0.0091,
#    'region': {'iso': 'AUS',
#     'name': 'Australia',
#     'province': 'South Australia',
#     'lat': '-34.9285',
#     'long': '138.6007',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 212,
#    'deaths': 11,
#    'recovered': 123,
#    'confirmed_diff': 5,
#    'deaths_diff': 1,
#    'recovered_diff': 6,
#    'last_update': '2020-04-27 02:31:20',
#    'active': 78,
#    'active_diff': -2,
#    'fatality_rate': 0.0519,
#    'region': {'iso': 'AUS',
#     'name': 'Australia',
#     'province': 'Tasmania',
#     'lat': '-41.4545',
#     'long': '145.9707',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 1349,
#    'deaths': 17,
#    'recovered': 1265,
#    'confirmed_diff': 3,
#    'deaths_diff': 1,
#    'recovered_diff': 1132,
#    'last_update': '2020-04-27 02:31:20',
#    'active': 67,
#    'active_diff': -1130,
#    'fatality_rate': 0.0126,
#    'region': {'iso': 'AUS',
#     'name': 'Australia',
#     'province': 'Victoria',
#     'lat': '-37.8136',
#     'long': '144.9631',
#     'cities': []}},
#   {'date': '2020-04-26',
#    'confirmed': 549,
#    'deaths': 8,
#    'recovered': 486,
#    'confirmed_diff': 0,
#    'deaths_diff': 0,
#    'recovered_diff': 8,
#    'last_update': '2020-04-27 02:31:20',
#    'active': 55,
#    'active_diff': -8,
#    'fatality_rate': 0.0146,
#    'region': {'iso': 'AUS',
#     'name': 'Australia',
#     'province': 'Western Australia',
#     'lat': '-31.9505',
#     'long': '115.8605',
#     'cities': []}}]}
